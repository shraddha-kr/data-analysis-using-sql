# %% [markdown]
# #### Case Study
# The new ZoomZoom
# Bat Scooter is now available for sale exclusively through its website. Sales are looking
# good, but suddenly, pre-orders start plunging by 20% after a couple of weeks. What's
# going on?

# %% [markdown]
# #### Method
# The method used to solve the above problem is about testing guesses or **(hypotheses)** using the collected data. Following are the key steps:
# 1. Define the question to answer what caused the drop-in sales of the Bat Scooter
# after approximately 2 weeks.
# 2. Complete background research to gather sufficient information to propose an
# initial hypothesis for the event or phenomenon.
# 3. Construct a hypothesis to explain the event or answer the question.
# 4. Define and execute an objective experiment to test the hypothesis. In an ideal
# scenario, all aspects of the experiment should be controlled and fixed, except for
# the phenomenon that is being tested under the hypothesis.
# 5. Analyze the data collected during the experiment.
# 6. Report the result of the analysis, which will hopefully explain why there was a drop
# in the sale of Bat Scooters.

# %% [markdown]
# #### Local-Setup
#
# * pip install ipython-sql
#
# * pip install psycopg2
#
# * pip install pgspecial

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://postgres:root@localhost/sqlda

# %%
pg_version=%sql select version()
print(pg_version)
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 1 rows affected.
# +------------------------------------------------------------+
# |                          version                           |
# +------------------------------------------------------------+
# | PostgreSQL 12.4, compiled by Visual C++ build 1914, 64-bit |
# +------------------------------------------------------------+

# %%
# %sql \dt
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 12 rows affected.
# [('public', 'closest_dealerships', 'table', 'postgres'),
#  ('public', 'countries', 'table', 'postgres'),
#  ('public', 'customer_sales', 'table', 'postgres'),
#  ('public', 'customer_survey', 'table', 'postgres'),
#  ('public', 'customers', 'table', 'postgres'),
#  ('public', 'dealerships', 'table', 'postgres'),
#  ('public', 'emails', 'table', 'postgres'),
#  ('public', 'products', 'table', 'postgres'),
#  ('public', 'public_transportation_by_zip', 'table', 'postgres'),
#  ('public', 'sales', 'table', 'postgres'),
#  ('public', 'salespeople', 'table', 'postgres'),
#  ('public', 'top_cities_data', 'table', 'postgres')]

# %% [markdown]
# #### Preliminary Data Collection
# Goal is to answer the following questions
# * When was production started on the scooter?
# * How much was it selling for?
# * How does the Bat Scooter compare with other types of scooters
# in terms of price?

# %% [markdown]
# ##### Basic list of scooters with a base manufacturer suggesting a retail price and production date

# %%
# %%sql
# SELECT model, base_msrp, production_start_date
# FROM products
# WHERE product_type='scooter';
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 7 rows affected.
# [('Lemon', Decimal('399.99'), datetime.datetime(2010, 3, 3, 0, 0)),
#  ('Lemon Limited Edition', Decimal('799.99'), datetime.datetime(2011, 1, 3, 0, 0)),
#  ('Lemon', Decimal('499.99'), datetime.datetime(2013, 5, 1, 0, 0)),
#  ('Blade', Decimal('699.99'), datetime.datetime(2014, 6, 23, 0, 0)),
#  ('Bat', Decimal('599.99'), datetime.datetime(2016, 10, 10, 0, 0)),
#  ('Bat Limited Edition', Decimal('699.99'), datetime.datetime(2017, 2, 15, 0, 0)),
#  ('Lemon Zester', Decimal('349.99'), datetime.datetime(2019, 2, 4, 0, 0))]

# %% [markdown]
# ##### Reconcile product information with the available sales information
# Exract the model name and product IDs for the scooters available

# %%
# %%sql
# SELECT model, product_id
# FROM products
# WHERE product_type='scooter';
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 7 rows affected.
# [('Lemon', 1),
#  ('Lemon Limited Edition', 2),
#  ('Lemon', 3),
#  ('Blade', 5),
#  ('Bat', 7),
#  ('Bat Limited Edition', 8),
#  ('Lemon Zester', 12)]

# %% [markdown]
# Insert the results of this query into a new table

# %%
# %%sql
# SELECT model, product_id
# INTO product_names
# FROM products
# WHERE product_type='scooter';
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 7 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM product_names
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 7 rows affected.
# [('Lemon', 1),
#  ('Lemon Limited Edition', 2),
#  ('Lemon', 3),
#  ('Blade', 5),
#  ('Bat', 7),
#  ('Bat Limited Edition', 8),
#  ('Lemon Zester', 12)]

# %% [markdown]
# ##### Observations
# We can see that we have two scooter
# products with Bat in the name; **Bat and Bat Limited Edition**. The Bat Scooter,
# which started production on October 10, 2016, with a suggested retail price
# of **599.99**; and the **Bat Limited Edition** Scooter, which started production
# approximately 4 months later, on February 15, 2017, at a price of **699.99.**
# Looking at the product information supplied, we can see that the Bat Scooter
# is somewhat unique from a price perspective, being the only scooter with a
# suggested retail price of **599.99** There are two others at **699.99** and one at
# **499.99.**
#
# Similarly, if we consider the production start date in isolation, the original Bat
# Scooter is again unique in that it is the only scooter starting production in the **last
# quarter or even half of the year** (date format: YYYY-MM-DD). All other scooters
# start production in the first half of the year, with only the Blade scooter starting
# production in June.
#
# **We can see that the Bat Scooter lies between the price
# points of some of the other scooters and that it was also manufactured a lot later
# in the year compared to the others.**

# %% [markdown]
# #### Extracting the Sales Information
# Extract the Bat Scooter sales records
# We have a table, product_names, that contains both the model names and product IDs. We will need to combine this information with the sales
# records and extract only those for the Bat Scooter.

# %%
# %sql \d sales
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 6 rows affected.
# [['customer_id', 'bigint', ''],
#  ['product_id', 'bigint', ''],
#  ['sales_transaction_date', 'timestamp without time zone', ''],
#  ['sales_amount', 'double precision', ''],
#  ['channel', 'text', ''],
#  ['dealership_id', 'double precision', '']]

# %%
# %%sql
# SELECT model, customer_id,
#        sales_transaction_date, sales_amount,
#        channel, dealership_id
# INTO products_sales
# FROM sales
# INNER JOIN product_names
# ON sales.product_id=product_names.product_id;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 34284 rows affected.
# []

# %% [markdown]
# ##### Combined product sales table

# %%
# %%sql
# SELECT * FROM products_sales LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 5 rows affected.
# [('Lemon', 41604, datetime.datetime(2012, 3, 30, 22, 45, 29), 399.99, 'internet', None),
#  ('Lemon', 41531, datetime.datetime(2010, 9, 7, 22, 53, 16), 399.99, 'internet', None),
#  ('Lemon', 41443, datetime.datetime(2011, 5, 24, 2, 19, 11), 399.99, 'internet', None),
#  ('Lemon', 41291, datetime.datetime(2010, 8, 8, 14, 12, 52), 319.992, 'internet', None),
#  ('Lemon', 41084, datetime.datetime(2012, 1, 9, 3, 34, 52), 319.992, 'internet', None)]

# %% [markdown]
# ##### Sales accross scooter products

# %%
import psycopg2 as pg
import pandas as pd
import pandas.io.sql as psql

conn = pg.connect('host=localhost, dbname=sqlda user=postgres password=root')
df_products_sales = psql.read_sql('SELECT model, ROUND(SUM(sales_amount)) AS totalsales FROM products_sales GROUP BY model ORDER BY 2', conn)
print(df_products_sales)

df_products_sales.plot(kind='barh', x='model', y='totalsales', 
                       title='Sales across scooter products').legend(
    loc='lower right')
# Out:
#                    model  totalsales
# 0  Lemon Limited Edition     68159.0
# 1           Lemon Zester    375154.0
# 2                  Blade    693830.0
# 3    Bat Limited Edition   3881165.0
# 4                    Bat   4202270.0
# 5                  Lemon   8797910.0

# %% [markdown]
# ##### Total sale records for Bat model

# %%
# %%sql
# SELECT model, ROUND(SUM(sales_amount))
# FROM products_sales
# GROUP BY model
# ORDER BY 2
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 6 rows affected.
# [('Lemon Limited Edition', 68159.0),
#  ('Lemon Zester', 375154.0),
#  ('Blade', 693830.0),
#  ('Bat Limited Edition', 3881165.0),
#  ('Bat', 4202270.0),
#  ('Lemon', 8797910.0)]

# %% [markdown]
# ##### Ordering Bat Sales records by date

# %%
# %%sql
# SELECT *
# FROM products_sales
# WHERE model='Bat'
# ORDER BY sales_transaction_date ASC
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 10 rows affected.
# [('Bat', 4319, datetime.datetime(2016, 10, 10, 0, 41, 57), 599.99, 'internet', None),
#  ('Bat', 40250, datetime.datetime(2016, 10, 10, 2, 47, 28), 599.99, 'dealership', 4.0),
#  ('Bat', 35497, datetime.datetime(2016, 10, 10, 4, 21, 8), 599.99, 'dealership', 2.0),
#  ('Bat', 4553, datetime.datetime(2016, 10, 10, 7, 42, 59), 599.99, 'dealership', 11.0),
#  ('Bat', 11678, datetime.datetime(2016, 10, 10, 9, 21, 8), 599.99, 'internet', None),
#  ('Bat', 45868, datetime.datetime(2016, 10, 10, 10, 29, 29), 599.99, 'internet', None),
#  ('Bat', 24125, datetime.datetime(2016, 10, 10, 18, 57, 25), 599.99, 'dealership', 1.0),
#  ('Bat', 31307, datetime.datetime(2016, 10, 10, 21, 22, 38), 599.99, 'internet', None),
#  ('Bat', 42213, datetime.datetime(2016, 10, 10, 21, 27, 36), 599.99, 'internet', None),
#  ('Bat', 47790, datetime.datetime(2016, 10, 11, 1, 28, 58), 599.99, 'dealership', 20.0)]

# %%
# %%sql
# SELECT COUNT(model) FROM products_sales WHERE model='Bat';
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 1 rows affected.
# [(7328,)]

# %% [markdown]
# ##### Total time frame of Bat sale records

# %%
# %%sql
# SELECT MIN(sales_transaction_date) as MIN,
#        MAX(sales_transaction_date) as MAX
# FROM products_sales
# WHERE model='Bat';
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 1 rows affected.
# [(datetime.datetime(2016, 10, 10, 0, 41, 57), datetime.datetime(2019, 5, 31, 22, 15, 30))]

# %% [markdown]
# ##### Total sales of Bat date wise

# %%
# %%sql
# SELECT *
# INTO bat_sales
# FROM products_sales
# WHERE model='Bat'
# ORDER BY sales_transaction_date;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 7328 rows affected.
# []

# %%
# %%sql
# SELECT * FROM bat_sales LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 5 rows affected.
# [('Bat', 4319, datetime.datetime(2016, 10, 10, 0, 41, 57), 599.99, 'internet', None),
#  ('Bat', 40250, datetime.datetime(2016, 10, 10, 2, 47, 28), 599.99, 'dealership', 4.0),
#  ('Bat', 35497, datetime.datetime(2016, 10, 10, 4, 21, 8), 599.99, 'dealership', 2.0),
#  ('Bat', 4553, datetime.datetime(2016, 10, 10, 7, 42, 59), 599.99, 'dealership', 11.0),
#  ('Bat', 11678, datetime.datetime(2016, 10, 10, 9, 21, 8), 599.99, 'internet', None)]

# %% [markdown]
# ##### Remove timestamp  to group records by date

# %%
# %%sql
# UPDATE bat_sales SET sales_transaction_date=DATE(sales_transaction_date);
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 7328 rows affected.
# []

# %%
# %%sql
# SELECT * FROM bat_sales LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 5 rows affected.
# [('Bat', 16825, datetime.datetime(2017, 1, 31, 0, 0), 539.991, 'internet', None),
#  ('Bat', 11805, datetime.datetime(2017, 9, 15, 0, 0), 599.99, 'internet', None),
#  ('Bat', 29464, datetime.datetime(2018, 5, 10, 0, 0), 599.99, 'internet', None),
#  ('Bat', 46153, datetime.datetime(2018, 12, 6, 0, 0), 599.99, 'internet', None),
#  ('Bat', 28129, datetime.datetime(2019, 3, 2, 0, 0), 599.99, 'internet', None)]

# %% [markdown]
# ##### Bat Daily Sales

# %%
# %%sql
# SELECT sales_transaction_date AS sale_date,
# COUNT(sales_transaction_date) AS sale_count INTO bat_sales_daily
# FROM bat_sales
# GROUP BY sales_transaction_date
# ORDER BY sales_transaction_date;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 964 rows affected.
# []

# %% [markdown]
# ##### First 22 records(a little over 3 weeks), as sales were dropped after approx. first 2 weeks

# %%
# %%sql
# SELECT * FROM bat_sales_daily LIMIT 22
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 22 rows affected.
# [(datetime.datetime(2016, 10, 10, 0, 0), 9),
#  (datetime.datetime(2016, 10, 11, 0, 0), 6),
#  (datetime.datetime(2016, 10, 12, 0, 0), 10),
#  (datetime.datetime(2016, 10, 13, 0, 0), 10),
#  (datetime.datetime(2016, 10, 14, 0, 0), 5),
#  (datetime.datetime(2016, 10, 15, 0, 0), 10),
#  (datetime.datetime(2016, 10, 16, 0, 0), 14),
#  (datetime.datetime(2016, 10, 17, 0, 0), 9),
#  (datetime.datetime(2016, 10, 18, 0, 0), 11),
#  (datetime.datetime(2016, 10, 19, 0, 0), 12),
#  (datetime.datetime(2016, 10, 20, 0, 0), 10),
#  (datetime.datetime(2016, 10, 21, 0, 0), 6),
#  (datetime.datetime(2016, 10, 22, 0, 0), 2),
#  (datetime.datetime(2016, 10, 23, 0, 0), 5),
#  (datetime.datetime(2016, 10, 24, 0, 0), 6),
#  (datetime.datetime(2016, 10, 25, 0, 0), 9),
#  (datetime.datetime(2016, 10, 26, 0, 0), 2),
#  (datetime.datetime(2016, 10, 27, 0, 0), 4),
#  (datetime.datetime(2016, 10, 28, 0, 0), 7),
#  (datetime.datetime(2016, 10, 29, 0, 0), 5),
#  (datetime.datetime(2016, 10, 30, 0, 0), 5),
#  (datetime.datetime(2016, 10, 31, 0, 0), 3)]

# %%
df_daily_batsales = psql.read_sql('''
SELECT * FROM bat_sales_daily LIMIT 22''', conn)

df_daily_batsales.plot(kind='line', y='sale_count', x='sale_date',
                       title='First 3 weeks of Sales', xlabel='Sale Date', ylabel='Sale Count').legend(
    loc='upper right')

# %% [markdown]
# ##### Observations
# * We can see a drop-in sales after **October 20**, as there are **7 days** in the first **11 rows**
# that record **double-digit sales**, and none over the next 11 days.
#
# * At this stage, we can confirm that there has been a drop off in sales.
#
# **Unanswered Questions**
# * The extent of the reduction
# * The reason for the drop off in sales.

# %% [markdown]
# #### Quantifying the Sales Drop
# We identified the occurrence of the sales drop as being approximately 10 days after launch. Here, we will try to quantify the drop off in sales for the Bat Scooter.

# %% [markdown]
# ##### Cumulative sum of sales

# %%
# %%sql
# SELECT *,
# sum(sale_count) OVER (ORDER BY sale_date)
# INTO bat_sales_growth
# FROM bat_sales_daily;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 964 rows affected.
# []

# %%
# %%sql
# SELECT * FROM bat_sales_growth LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 10 rows affected.
# [(datetime.datetime(2016, 10, 10, 0, 0), 9, Decimal('9')),
#  (datetime.datetime(2016, 10, 11, 0, 0), 6, Decimal('15')),
#  (datetime.datetime(2016, 10, 12, 0, 0), 10, Decimal('25')),
#  (datetime.datetime(2016, 10, 13, 0, 0), 10, Decimal('35')),
#  (datetime.datetime(2016, 10, 14, 0, 0), 5, Decimal('40')),
#  (datetime.datetime(2016, 10, 15, 0, 0), 10, Decimal('50')),
#  (datetime.datetime(2016, 10, 16, 0, 0), 14, Decimal('64')),
#  (datetime.datetime(2016, 10, 17, 0, 0), 9, Decimal('73')),
#  (datetime.datetime(2016, 10, 18, 0, 0), 11, Decimal('84')),
#  (datetime.datetime(2016, 10, 19, 0, 0), 12, Decimal('96'))]

# %% [markdown]
# ##### Compute Lag between sales from 1 week before

# %%
# %%sql
# SELECT *,
# lag(sum, 7) OVER (ORDER BY sale_date)
# INTO bat_sales_daily_delay
# FROM bat_sales_growth
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 964 rows affected.
# []

# %% [markdown]
# Daily sales delay with lag

# %%
# %%sql
# SELECT * FROM bat_sales_daily_delay LIMIT 10
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 10 rows affected.
# [(datetime.datetime(2016, 10, 10, 0, 0), 9, Decimal('9'), None),
#  (datetime.datetime(2016, 10, 11, 0, 0), 6, Decimal('15'), None),
#  (datetime.datetime(2016, 10, 12, 0, 0), 10, Decimal('25'), None),
#  (datetime.datetime(2016, 10, 13, 0, 0), 10, Decimal('35'), None),
#  (datetime.datetime(2016, 10, 14, 0, 0), 5, Decimal('40'), None),
#  (datetime.datetime(2016, 10, 15, 0, 0), 10, Decimal('50'), None),
#  (datetime.datetime(2016, 10, 16, 0, 0), 14, Decimal('64'), None),
#  (datetime.datetime(2016, 10, 17, 0, 0), 9, Decimal('73'), Decimal('9')),
#  (datetime.datetime(2016, 10, 18, 0, 0), 11, Decimal('84'), Decimal('15')),
#  (datetime.datetime(2016, 10, 19, 0, 0), 12, Decimal('96'), Decimal('25'))]

# %% [markdown]
# ##### Compute the sales growth as a percentage
# The percentage sales volume can be calculated as below
# (new_volume-old_volume)/old_volume

# %%
# %%sql
# SELECT *, ROUND(((sum-lag)/lag)*100) AS volume_percent INTO bat_sales_delay_vol FROM
# bat_sales_daily_delay ;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 964 rows affected.
# []

# %% [markdown]
# Relative sales volume of the scooter over 3 weeks

# %%
# %%sql
# SELECT * FROM bat_sales_delay_vol LIMIT 22
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 22 rows affected.
# [(datetime.date(2016, 10, 10), 9, Decimal('9'), None, None),
#  (datetime.date(2016, 10, 11), 6, Decimal('15'), None, None),
#  (datetime.date(2016, 10, 12), 10, Decimal('25'), None, None),
#  (datetime.date(2016, 10, 13), 10, Decimal('35'), None, None),
#  (datetime.date(2016, 10, 14), 5, Decimal('40'), None, None),
#  (datetime.date(2016, 10, 15), 10, Decimal('50'), None, None),
#  (datetime.date(2016, 10, 16), 14, Decimal('64'), None, None),
#  (datetime.date(2016, 10, 17), 9, Decimal('73'), Decimal('9'), Decimal('711')),
#  (datetime.date(2016, 10, 18), 11, Decimal('84'), Decimal('15'), Decimal('460')),
#  (datetime.date(2016, 10, 19), 12, Decimal('96'), Decimal('25'), Decimal('284')),
#  (datetime.date(2016, 10, 20), 10, Decimal('106'), Decimal('35'), Decimal('203')),
#  (datetime.date(2016, 10, 21), 6, Decimal('112'), Decimal('40'), Decimal('180')),
#  (datetime.date(2016, 10, 22), 2, Decimal('114'), Decimal('50'), Decimal('128')),
#  (datetime.date(2016, 10, 23), 5, Decimal('119'), Decimal('64'), Decimal('86')),
#  (datetime.date(2016, 10, 24), 6, Decimal('125'), Decimal('73'), Decimal('71')),
#  (datetime.date(2016, 10, 25), 9, Decimal('134'), Decimal('84'), Decimal('60')),
#  (datetime.date(2016, 10, 26), 2, Decimal('136'), Decimal('96'), Decimal('42')),
#  (datetime.date(2016, 10, 27), 4, Decimal('140'), Decimal('106'), Decimal('32')),
#  (datetime.date(2016, 10, 28), 7, Decimal('147'), Decimal('112'), Decimal('31')),
#  (datetime.date(2016, 10, 29), 5, Decimal('152'), Decimal('114'), Decimal('33')),
#  (datetime.date(2016, 10, 30), 5, Decimal('157'), Decimal('119'), Decimal('32')),
#  (datetime.date(2016, 10, 31), 3, Decimal('160'), Decimal('125'), Decimal('28'))]

# %% [markdown]
# Looking at the output table, we can see four sets of information: the daily sales
# count, the cumulative sum of the daily sales count, the cumulative sum offset by 1
# week (the lag), and the relative daily sales volume.
#
# While the count and cumulative sum columns are reasonably straightforward, why do
# we need the lag and volume columns? This is because we are looking for drops in sales
# growth over the first couple of weeks, hence, we compare the daily sum of sales to the
# same values 7 days earlier (the lag). By subtracting the sum and lag values and dividing
# by the lag, we obtain the volume value and can determine sales growth compared to the
# previous week.
#
# Notice that the sales volume on October 17 is 700% above that of the launch date of
# October 10. By October 22, the volume is over double that of the week prior. As time
# passes, this relative difference begins to decrease dramatically. By the end of October,
# the volume is 28% higher than the week prior. At this stage, we have observed and
# confirmed the presence of a reduction in sales growth after the first 2 weeks. The next
# stage is to attempt to explain the causes of the reduction.

# %% [markdown]
# #### Launch Time Analysis
# Let's try to identify the causes of a sales drop. We will test the hypothesis that the timing of the scooter launch attributed to the reduction in sales. Preliminary data collection we had observed that Bat scooter was launched on October 10, 2016.
#
# In order to determine whether the
# launch date attributed to the sales drop, we need to compare the ZoomZoom
# Bat Scooter to other scooter products according to the launch date.

# %%
# %%sql
# SELECT * FROM products WHERE product_type='scooter';
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 7 rows affected.
# [(1, 'Lemon', 2010, 'scooter', Decimal('399.99'), datetime.datetime(2010, 3, 3, 0, 0), datetime.datetime(2012, 6, 8, 0, 0)),
#  (2, 'Lemon Limited Edition', 2011, 'scooter', Decimal('799.99'), datetime.datetime(2011, 1, 3, 0, 0), datetime.datetime(2011, 3, 30, 0, 0)),
#  (3, 'Lemon', 2013, 'scooter', Decimal('499.99'), datetime.datetime(2013, 5, 1, 0, 0), datetime.datetime(2018, 12, 28, 0, 0)),
#  (5, 'Blade', 2014, 'scooter', Decimal('699.99'), datetime.datetime(2014, 6, 23, 0, 0), datetime.datetime(2015, 1, 27, 0, 0)),
#  (7, 'Bat', 2016, 'scooter', Decimal('599.99'), datetime.datetime(2016, 10, 10, 0, 0), None),
#  (8, 'Bat Limited Edition', 2017, 'scooter', Decimal('699.99'), datetime.datetime(2017, 2, 15, 0, 0), None),
#  (12, 'Lemon Zester', 2019, 'scooter', Decimal('349.99'), datetime.datetime(2019, 2, 4, 0, 0), None)]

# %% [markdown]
# ##### Choose a control group to test the hypothesis
# To test the hypothesis that the time of year had an impact on sales performance,
# we require a scooter model to use as the **control or reference group**. In an ideal
# world, we could launch the ZoomZoom Bat Scooter in a different location or
# region, for example, but just at a different time, and then compare the two.
# However, we cannot do this here. Instead, we will choose a similar scooter
# launched at a different time. There are several different options in the product
# database, each with its own similarities and differences to the experimental
# group (ZoomZoom Bat Scooter). In our opinion, the Bat Limited Edition Scooter is
# suitable for comparison **(the control group)**. It is slightly more expensive, but it was
# launched only 4 months after the Bat Scooter. Looking at its name, the Bat Limited
# Edition Scooter seems to share most of the same features, with a number of extras
# given that it's a "limited edition."

# %%
# %%sql
# SELECT products.model, sales.sales_transaction_date
# INTO bat_ltd_sales
# FROM sales
# INNER JOIN products
# ON sales.product_id=products.product_id
# WHERE sales.product_id=8
# ORDER BY sales.sales_transaction_date;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 5803 rows affected.
# []

# %%
# %%sql
# SELECT * FROM bat_ltd_sales LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 5 rows affected.
# [('Bat Limited Edition', datetime.datetime(2017, 2, 15, 1, 49, 2)),
#  ('Bat Limited Edition', datetime.datetime(2017, 2, 15, 9, 42, 37)),
#  ('Bat Limited Edition', datetime.datetime(2017, 2, 15, 10, 48, 31)),
#  ('Bat Limited Edition', datetime.datetime(2017, 2, 15, 12, 22, 41)),
#  ('Bat Limited Edition', datetime.datetime(2017, 2, 15, 13, 51, 34))]

# %% [markdown]
# ##### Total no of sales for Bat Limited Edition

# %%
# %%sql
# SELECT COUNT(model) FROM bat_ltd_sales;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 1 rows affected.
# [(5803,)]

# %% [markdown]
# This is compared to the original Bat Scooter, which sold **7,328** items.

# %% [markdown]
# Adjust the date to cast the transaction date column as a date, discarding the time information

# %%
# %%sql
# ALTER TABLE bat_ltd_sales
# ALTER COLUMN sales_transaction_date
# TYPE date;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# Done.
# []

# %%
# %%sql
# SELECT * FROM bat_ltd_sales LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 5 rows affected.
# [('Bat Limited Edition', datetime.date(2017, 2, 15)),
#  ('Bat Limited Edition', datetime.date(2017, 2, 15)),
#  ('Bat Limited Edition', datetime.date(2017, 2, 15)),
#  ('Bat Limited Edition', datetime.date(2017, 2, 15)),
#  ('Bat Limited Edition', datetime.date(2017, 2, 15))]

# %% [markdown]
# ##### Bat Limited Edition Daily Sales

# %%
# %%sql
# SELECT sales_transaction_date, count(sales_transaction_date)
# INTO bat_ltd_sales_count
# FROM bat_ltd_sales
# GROUP BY sales_transaction_date
# ORDER BY sales_transaction_date;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 836 rows affected.
# []

# %%
# %%sql
# SELECT * FROM bat_ltd_sales_count;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 836 rows affected.
# [(datetime.date(2017, 2, 15), 6),
#  (datetime.date(2017, 2, 16), 2),
#  (datetime.date(2017, 2, 17), 1),
#  (datetime.date(2017, 2, 18), 4),
#  (datetime.date(2017, 2, 19), 5),
#  (datetime.date(2017, 2, 20), 6),
#  (datetime.date(2017, 2, 21), 5),
#  (datetime.date(2017, 2, 22), 4),
#  (datetime.date(2017, 2, 23), 6),
#  (datetime.date(2017, 2, 24), 2),
#  (datetime.date(2017, 2, 25), 2),
#  (datetime.date(2017, 2, 26), 2),
#  (datetime.date(2017, 2, 27), 4),
#  (datetime.date(2017, 2, 28), 4),
#  (datetime.date(2017, 3, 1), 5),
#  (datetime.date(2017, 3, 2), 1),
#  (datetime.date(2017, 3, 3), 3),
#  (datetime.date(2017, 3, 4), 8),
#  (datetime.date(2017, 3, 5), 4),
#  (datetime.date(2017, 3, 6), 7),
#  (datetime.date(2017, 3, 7), 7),
#  (datetime.date(2017, 3, 8), 8),
#  (datetime.date(2017, 3, 9), 3),
#  (datetime.date(2017, 3, 10), 7),
#  (datetime.date(2017, 3, 11), 4),
#  (datetime.date(2017, 3, 12), 9),
#  (datetime.date(2017, 3, 13), 3),
#  (datetime.date(2017, 3, 14), 6),
#  (datetime.date(2017, 3, 15), 3),
#  (datetime.date(2017, 3, 16), 2),
#  (datetime.date(2017, 3, 17), 5),
#  (datetime.date(2017, 3, 18), 7),
#  (datetime.date(2017, 3, 19), 2),
#  (datetime.date(2017, 3, 20), 5),
#  (datetime.date(2017, 3, 21), 7),
#  (datetime.date(2017, 3, 22), 6),
#  (datetime.date(2017, 3, 23), 3),
#  (datetime.date(2017, 3, 24), 9),
#  (datetime.date(2017, 3, 25), 5),
#  (datetime.date(2017, 3, 26), 6),
#  (datetime.date(2017, 3, 27), 3),
#  (datetime.date(2017, 3, 28), 7),
#  (datetime.date(2017, 3, 29), 1),
#  (datetime.date(2017, 3, 30), 6),
#  (datetime.date(2017, 3, 31), 3),
#  (datetime.date(2017, 4, 1), 6),
#  (datetime.date(2017, 4, 2), 3),
#  (datetime.date(2017, 4, 3), 4),
#  (datetime.date(2017, 4, 4), 8),
#  (datetime.date(2017, 4, 5), 6),
#  (datetime.date(2017, 4, 6), 6),
#  (datetime.date(2017, 4, 7), 4),
#  (datetime.date(2017, 4, 8), 4),
#  (datetime.date(2017, 4, 9), 5),
#  (datetime.date(2017, 4, 10), 10),
#  (datetime.date(2017, 4, 11), 3),
#  (datetime.date(2017, 4, 12), 4),
#  (datetime.date(2017, 4, 13), 7),
#  (datetime.date(2017, 4, 14), 11),
#  (datetime.date(2017, 4, 15), 5),
#  (datetime.date(2017, 4, 16), 8),
#  (datetime.date(2017, 4, 17), 4),
#  (datetime.date(2017, 4, 18), 6),
#  (datetime.date(2017, 4, 19), 6),
#  (datetime.date(2017, 4, 20), 6),
#  (datetime.date(2017, 4, 21), 7),
#  (datetime.date(2017, 4, 22), 12),
#  (datetime.date(2017, 4, 23), 4),
#  (datetime.date(2017, 4, 24), 6),
#  (datetime.date(2017, 4, 25), 3),
#  (datetime.date(2017, 4, 26), 2),
#  (datetime.date(2017, 4, 27), 4),
#  (datetime.date(2017, 4, 28), 4),
#  (datetime.date(2017, 4, 29), 5),
#  (datetime.date(2017, 4, 30), 5),
#  (datetime.date(2017, 5, 1), 4),
#  (datetime.date(2017, 5, 2), 5),
#  (datetime.date(2017, 5, 3), 7),
#  (datetime.date(2017, 5, 4), 9),
#  (datetime.date(2017, 5, 5), 3),
#  (datetime.date(2017, 5, 6), 10),
#  (datetime.date(2017, 5, 7), 4),
#  (datetime.date(2017, 5, 8), 10),
#  (datetime.date(2017, 5, 9), 10),
#  (datetime.date(2017, 5, 10), 3),
#  (datetime.date(2017, 5, 11), 10),
#  (datetime.date(2017, 5, 12), 7),
#  (datetime.date(2017, 5, 13), 10),
#  (datetime.date(2017, 5, 14), 5),
#  (datetime.date(2017, 5, 15), 2),
#  (datetime.date(2017, 5, 16), 7),
#  (datetime.date(2017, 5, 17), 5),
#  (datetime.date(2017, 5, 18), 3),
#  (datetime.date(2017, 5, 19), 9),
#  (datetime.date(2017, 5, 20), 7),
#  (datetime.date(2017, 5, 21), 4),
#  (datetime.date(2017, 5, 22), 6),
#  (datetime.date(2017, 5, 23), 6),
#  (datetime.date(2017, 5, 24), 14),
#  (datetime.date(2017, 5, 25), 14),
#  (datetime.date(2017, 5, 26), 4),
#  (datetime.date(2017, 5, 27), 5),
#  (datetime.date(2017, 5, 28), 6),
#  (datetime.date(2017, 5, 29), 4),
#  (datetime.date(2017, 5, 30), 9),
#  (datetime.date(2017, 5, 31), 4),
#  (datetime.date(2017, 6, 1), 16),
#  (datetime.date(2017, 6, 2), 5),
#  (datetime.date(2017, 6, 3), 1),
#  (datetime.date(2017, 6, 4), 6),
#  (datetime.date(2017, 6, 5), 8),
#  (datetime.date(2017, 6, 6), 8),
#  (datetime.date(2017, 6, 7), 7),
#  (datetime.date(2017, 6, 8), 11),
#  (datetime.date(2017, 6, 9), 4),
#  (datetime.date(2017, 6, 10), 10),
#  (datetime.date(2017, 6, 11), 5),
#  (datetime.date(2017, 6, 12), 9),
#  (datetime.date(2017, 6, 13), 6),
#  (datetime.date(2017, 6, 14), 11),
#  (datetime.date(2017, 6, 15), 9),
#  (datetime.date(2017, 6, 16), 7),
#  (datetime.date(2017, 6, 17), 7),
#  (datetime.date(2017, 6, 18), 7),
#  (datetime.date(2017, 6, 19), 3),
#  (datetime.date(2017, 6, 20), 12),
#  (datetime.date(2017, 6, 21), 11),
#  (datetime.date(2017, 6, 22), 8),
#  (datetime.date(2017, 6, 23), 14),
#  (datetime.date(2017, 6, 24), 8),
#  (datetime.date(2017, 6, 25), 9),
#  (datetime.date(2017, 6, 26), 9),
#  (datetime.date(2017, 6, 27), 10),
#  (datetime.date(2017, 6, 28), 9),
#  (datetime.date(2017, 6, 29), 14),
#  (datetime.date(2017, 6, 30), 12),
#  (datetime.date(2017, 7, 1), 6),
#  (datetime.date(2017, 7, 2), 7),
#  (datetime.date(2017, 7, 3), 9),
#  (datetime.date(2017, 7, 4), 9),
#  (datetime.date(2017, 7, 5), 11),
#  (datetime.date(2017, 7, 6), 10),
#  (datetime.date(2017, 7, 7), 3),
#  (datetime.date(2017, 7, 8), 14),
#  (datetime.date(2017, 7, 9), 12),
#  (datetime.date(2017, 7, 10), 9),
#  (datetime.date(2017, 7, 11), 10),
#  (datetime.date(2017, 7, 12), 8),
#  (datetime.date(2017, 7, 13), 8),
#  (datetime.date(2017, 7, 14), 3),
#  (datetime.date(2017, 7, 15), 6),
#  (datetime.date(2017, 7, 16), 14),
#  (datetime.date(2017, 7, 17), 8),
#  (datetime.date(2017, 7, 18), 6),
#  (datetime.date(2017, 7, 19), 11),
#  (datetime.date(2017, 7, 20), 12),
#  (datetime.date(2017, 7, 21), 12),
#  (datetime.date(2017, 7, 22), 11),
#  (datetime.date(2017, 7, 23), 2),
#  (datetime.date(2017, 7, 24), 8),
#  (datetime.date(2017, 7, 25), 8),
#  (datetime.date(2017, 7, 26), 8),
#  (datetime.date(2017, 7, 27), 8),
#  (datetime.date(2017, 7, 28), 7),
#  (datetime.date(2017, 7, 29), 8),
#  (datetime.date(2017, 7, 30), 9),
#  (datetime.date(2017, 7, 31), 14),
#  (datetime.date(2017, 8, 1), 10),
#  (datetime.date(2017, 8, 2), 6),
#  (datetime.date(2017, 8, 3), 9),
#  (datetime.date(2017, 8, 4), 7),
#  (datetime.date(2017, 8, 5), 8),
#  (datetime.date(2017, 8, 6), 7),
#  (datetime.date(2017, 8, 7), 8),
#  (datetime.date(2017, 8, 8), 8),
#  (datetime.date(2017, 8, 9), 5),
#  (datetime.date(2017, 8, 10), 9),
#  (datetime.date(2017, 8, 11), 12),
#  (datetime.date(2017, 8, 12), 7),
#  (datetime.date(2017, 8, 13), 9),
#  (datetime.date(2017, 8, 14), 7),
#  (datetime.date(2017, 8, 15), 7),
#  (datetime.date(2017, 8, 16), 9),
#  (datetime.date(2017, 8, 17), 14),
#  (datetime.date(2017, 8, 18), 7),
#  (datetime.date(2017, 8, 19), 10),
#  (datetime.date(2017, 8, 20), 13),
#  (datetime.date(2017, 8, 21), 10),
#  (datetime.date(2017, 8, 22), 7),
#  (datetime.date(2017, 8, 23), 8),
#  (datetime.date(2017, 8, 24), 4),
#  (datetime.date(2017, 8, 25), 9),
#  (datetime.date(2017, 8, 26), 8),
#  (datetime.date(2017, 8, 27), 9),
#  (datetime.date(2017, 8, 28), 7),
#  (datetime.date(2017, 8, 29), 5),
#  (datetime.date(2017, 8, 30), 11),
#  (datetime.date(2017, 8, 31), 7),
#  (datetime.date(2017, 9, 1), 9),
#  (datetime.date(2017, 9, 2), 8),
#  (datetime.date(2017, 9, 3), 6),
#  (datetime.date(2017, 9, 4), 11),
#  (datetime.date(2017, 9, 5), 6),
#  (datetime.date(2017, 9, 6), 7),
#  (datetime.date(2017, 9, 7), 9),
#  (datetime.date(2017, 9, 8), 7),
#  (datetime.date(2017, 9, 9), 9),
#  (datetime.date(2017, 9, 10), 5),
#  (datetime.date(2017, 9, 11), 6),
#  (datetime.date(2017, 9, 12), 8),
#  (datetime.date(2017, 9, 13), 6),
#  (datetime.date(2017, 9, 14), 10),
#  (datetime.date(2017, 9, 15), 11),
#  (datetime.date(2017, 9, 16), 11),
#  (datetime.date(2017, 9, 17), 8),
#  (datetime.date(2017, 9, 18), 4),
#  (datetime.date(2017, 9, 19), 5),
#  (datetime.date(2017, 9, 20), 8),
#  (datetime.date(2017, 9, 21), 9),
#  (datetime.date(2017, 9, 22), 7),
#  (datetime.date(2017, 9, 23), 7),
#  (datetime.date(2017, 9, 24), 7),
#  (datetime.date(2017, 9, 25), 7),
#  (datetime.date(2017, 9, 26), 5),
#  (datetime.date(2017, 9, 27), 6),
#  (datetime.date(2017, 9, 28), 7),
#  (datetime.date(2017, 9, 29), 5),
#  (datetime.date(2017, 9, 30), 9),
#  (datetime.date(2017, 10, 1), 5),
#  (datetime.date(2017, 10, 2), 10),
#  (datetime.date(2017, 10, 3), 8),
#  (datetime.date(2017, 10, 4), 4),
#  (datetime.date(2017, 10, 5), 2),
#  (datetime.date(2017, 10, 6), 7),
#  (datetime.date(2017, 10, 7), 4),
#  (datetime.date(2017, 10, 8), 9),
#  (datetime.date(2017, 10, 9), 8),
#  (datetime.date(2017, 10, 10), 12),
#  (datetime.date(2017, 10, 11), 6),
#  (datetime.date(2017, 10, 12), 7),
#  (datetime.date(2017, 10, 13), 4),
#  (datetime.date(2017, 10, 14), 7),
#  (datetime.date(2017, 10, 15), 7),
#  (datetime.date(2017, 10, 16), 3),
#  (datetime.date(2017, 10, 17), 10),
#  (datetime.date(2017, 10, 18), 2),
#  (datetime.date(2017, 10, 19), 4),
#  (datetime.date(2017, 10, 20), 5),
#  (datetime.date(2017, 10, 21), 4),
#  (datetime.date(2017, 10, 22), 8),
#  (datetime.date(2017, 10, 23), 6),
#  (datetime.date(2017, 10, 24), 11),
#  (datetime.date(2017, 10, 25), 7),
#  (datetime.date(2017, 10, 26), 7),
#  (datetime.date(2017, 10, 27), 8),
#  (datetime.date(2017, 10, 28), 4),
#  (datetime.date(2017, 10, 29), 6),
#  (datetime.date(2017, 10, 30), 6),
#  (datetime.date(2017, 10, 31), 8),
#  (datetime.date(2017, 11, 1), 5),
#  (datetime.date(2017, 11, 2), 4),
#  (datetime.date(2017, 11, 3), 13),
#  (datetime.date(2017, 11, 4), 9),
#  (datetime.date(2017, 11, 5), 5),
#  (datetime.date(2017, 11, 6), 9),
#  (datetime.date(2017, 11, 7), 6),
#  (datetime.date(2017, 11, 8), 5),
#  (datetime.date(2017, 11, 9), 5),
#  (datetime.date(2017, 11, 10), 6),
#  (datetime.date(2017, 11, 11), 3),
#  (datetime.date(2017, 11, 12), 3),
#  (datetime.date(2017, 11, 13), 4),
#  (datetime.date(2017, 11, 14), 6),
#  (datetime.date(2017, 11, 15), 7),
#  (datetime.date(2017, 11, 16), 6),
#  (datetime.date(2017, 11, 17), 9),
#  (datetime.date(2017, 11, 18), 9),
#  (datetime.date(2017, 11, 19), 4),
#  (datetime.date(2017, 11, 20), 7),
#  (datetime.date(2017, 11, 21), 2),
#  (datetime.date(2017, 11, 22), 5),
#  (datetime.date(2017, 11, 23), 6),
#  (datetime.date(2017, 11, 24), 6),
#  (datetime.date(2017, 11, 25), 8),
#  (datetime.date(2017, 11, 26), 6),
#  (datetime.date(2017, 11, 27), 4),
#  (datetime.date(2017, 11, 28), 7),
#  (datetime.date(2017, 11, 29), 1),
#  (datetime.date(2017, 11, 30), 14),
#  (datetime.date(2017, 12, 1), 3),
#  (datetime.date(2017, 12, 2), 2),
#  (datetime.date(2017, 12, 3), 7),
#  (datetime.date(2017, 12, 4), 4),
#  (datetime.date(2017, 12, 5), 7),
#  (datetime.date(2017, 12, 6), 8),
#  (datetime.date(2017, 12, 7), 4),
#  (datetime.date(2017, 12, 8), 2),
#  (datetime.date(2017, 12, 9), 3),
#  (datetime.date(2017, 12, 10), 7),
#  (datetime.date(2017, 12, 11), 7),
#  (datetime.date(2017, 12, 12), 6),
#  (datetime.date(2017, 12, 13), 5),
#  (datetime.date(2017, 12, 14), 2),
#  (datetime.date(2017, 12, 15), 3),
#  (datetime.date(2017, 12, 16), 8),
#  (datetime.date(2017, 12, 17), 7),
#  (datetime.date(2017, 12, 18), 10),
#  (datetime.date(2017, 12, 19), 4),
#  (datetime.date(2017, 12, 20), 2),
#  (datetime.date(2017, 12, 21), 5),
#  (datetime.date(2017, 12, 22), 5),
#  (datetime.date(2017, 12, 23), 5),
#  (datetime.date(2017, 12, 24), 5),
#  (datetime.date(2017, 12, 25), 7),
#  (datetime.date(2017, 12, 26), 4),
#  (datetime.date(2017, 12, 27), 4),
#  (datetime.date(2017, 12, 28), 5),
#  (datetime.date(2017, 12, 29), 3),
#  (datetime.date(2017, 12, 30), 4),
#  (datetime.date(2017, 12, 31), 2),
#  (datetime.date(2018, 1, 1), 2),
#  (datetime.date(2018, 1, 2), 7),
#  (datetime.date(2018, 1, 3), 3),
#  (datetime.date(2018, 1, 4), 6),
#  (datetime.date(2018, 1, 5), 4),
#  (datetime.date(2018, 1, 6), 3),
#  (datetime.date(2018, 1, 7), 5),
#  (datetime.date(2018, 1, 8), 6),
#  (datetime.date(2018, 1, 9), 3),
#  (datetime.date(2018, 1, 10), 5),
#  (datetime.date(2018, 1, 11), 3),
#  (datetime.date(2019, 5, 14), 15),
#  (datetime.date(2019, 5, 15), 13),
#  (datetime.date(2019, 5, 16), 3),
#  (datetime.date(2019, 5, 17), 11),
#  (datetime.date(2019, 5, 18), 7),
#  (datetime.date(2019, 5, 19), 7),
#  (datetime.date(2019, 5, 20), 9),
#  (datetime.date(2019, 5, 21), 9),
#  (datetime.date(2019, 5, 22), 9),
#  (datetime.date(2019, 5, 23), 6),
#  (datetime.date(2019, 5, 24), 9),
#  (datetime.date(2019, 5, 25), 6),
#  (datetime.date(2019, 5, 26), 6),
#  (datetime.date(2019, 5, 27), 4),
#  (datetime.date(2019, 5, 28), 13),
#  (datetime.date(2019, 5, 29), 9),
#  (datetime.date(2019, 5, 30), 12),
#  (datetime.date(2019, 5, 31), 5)]

# %% [markdown]
# ##### Cumulative sum of daily sales

# %%
# %%sql
# SELECT *, sum(count) OVER (ORDER BY sales_transaction_date) INTO
# bat_ltd_sales_growth FROM bat_ltd_sales_count;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 836 rows affected.
# []

# %%
# %%sql
# SELECT * FROM bat_ltd_sales_growth LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 5 rows affected.
# [(datetime.date(2017, 2, 15), 6, Decimal('6')),
#  (datetime.date(2017, 2, 16), 2, Decimal('8')),
#  (datetime.date(2017, 2, 17), 1, Decimal('9')),
#  (datetime.date(2017, 2, 18), 4, Decimal('13')),
#  (datetime.date(2017, 2, 19), 5, Decimal('18'))]

# %% [markdown]
# ##### Compute the 7-day lag function

# %%
# %%sql
# SELECT *, lag(sum , 7) OVER (ORDER BY sales_transaction_date) INTO
# bat_ltd_sales_delay FROM bat_ltd_sales_growth;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 836 rows affected.
# []

# %%
# %%sql
# SELECT * FROM bat_ltd_sales_delay LIMIT 5
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 5 rows affected.
# [(datetime.date(2017, 2, 15), 6, Decimal('6'), None),
#  (datetime.date(2017, 2, 16), 2, Decimal('8'), None),
#  (datetime.date(2017, 2, 17), 1, Decimal('9'), None),
#  (datetime.date(2017, 2, 18), 4, Decimal('13'), None),
#  (datetime.date(2017, 2, 19), 5, Decimal('18'), None)]

# %% [markdown]
# ##### Compute Sales Growth

# %%
# %%sql
# SELECT *,
# ROUND(((sum-lag)/lag)*100) AS volume_percent
# INTO bat_ltd_sales_vol
# FROM bat_ltd_sales_delay;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 836 rows affected.
# []

# %%
# %%sql
# SELECT * FROM bat_ltd_sales_vol LIMIT 22;
# Out:
#  * postgresql://postgres:***@localhost/sqlda
# 22 rows affected.
# [(datetime.date(2017, 2, 15), 6, Decimal('6'), None, None),
#  (datetime.date(2017, 2, 16), 2, Decimal('8'), None, None),
#  (datetime.date(2017, 2, 17), 1, Decimal('9'), None, None),
#  (datetime.date(2017, 2, 18), 4, Decimal('13'), None, None),
#  (datetime.date(2017, 2, 19), 5, Decimal('18'), None, None),
#  (datetime.date(2017, 2, 20), 6, Decimal('24'), None, None),
#  (datetime.date(2017, 2, 21), 5, Decimal('29'), None, None),
#  (datetime.date(2017, 2, 22), 4, Decimal('33'), Decimal('6'), Decimal('450')),
#  (datetime.date(2017, 2, 23), 6, Decimal('39'), Decimal('8'), Decimal('388')),
#  (datetime.date(2017, 2, 24), 2, Decimal('41'), Decimal('9'), Decimal('356')),
#  (datetime.date(2017, 2, 25), 2, Decimal('43'), Decimal('13'), Decimal('231')),
#  (datetime.date(2017, 2, 26), 2, Decimal('45'), Decimal('18'), Decimal('150')),
#  (datetime.date(2017, 2, 27), 4, Decimal('49'), Decimal('24'), Decimal('104')),
#  (datetime.date(2017, 2, 28), 4, Decimal('53'), Decimal('29'), Decimal('83')),
#  (datetime.date(2017, 3, 1), 5, Decimal('58'), Decimal('33'), Decimal('76')),
#  (datetime.date(2017, 3, 2), 1, Decimal('59'), Decimal('39'), Decimal('51')),
#  (datetime.date(2017, 3, 3), 3, Decimal('62'), Decimal('41'), Decimal('51')),
#  (datetime.date(2017, 3, 4), 8, Decimal('70'), Decimal('43'), Decimal('63')),
#  (datetime.date(2017, 3, 5), 4, Decimal('74'), Decimal('45'), Decimal('64')),
#  (datetime.date(2017, 3, 6), 7, Decimal('81'), Decimal('49'), Decimal('65')),
#  (datetime.date(2017, 3, 7), 7, Decimal('88'), Decimal('53'), Decimal('66')),
#  (datetime.date(2017, 3, 8), 8, Decimal('96'), Decimal('58'), Decimal('66'))]

# %%
import psycopg2 as pg
import pandas as pd
import pandas.io.sql as psql

conn = pg.connect('host=localhost, dbname=sqlda user=postgres password=root')

df_batltd_salevol = psql.read_sql('''
SELECT sales_transaction_date, volume_percent 
FROM bat_ltd_sales_vol 
LIMIT 22''', conn)

df_batltd_salevol.plot(kind='bar', y='volume_percent', x='sales_transaction_date',
                       title='Bat Limited Edition first 3 weeks of Sales', 
                       xlabel='Sale Date', ylabel='Sale Volume Percent',
                       alpha=0.75, rot=50, ylim=(0, 100), figsize=(10,5), grid=True).legend(
    loc='upper right')

df_bat_salevol = psql.read_sql('''
SELECT sale_date, volume_percent 
FROM bat_sales_delay_vol 
LIMIT 22''', conn)

df_bat_salevol.plot(kind='bar', y='volume_percent', x='sale_date',
                    title='Bat Edition first 3 weeks of Sales', 
                    xlabel='Sale Date', ylabel='Sale Volume Percent',
                    alpha=0.75, rot=50, ylim=(0, 100), figsize=(10,5), 
                    grid=True).legend(
    loc='upper right')

# %% [markdown]
# ##### Observations
# Looking at the volume column in the preceding diagram, we can again see that
# the sales growth is more consistent than the original Bat Scooter. The growth
# within the first week is less than that of the original model, but it is sustained
# over a longer period. After 22 days of sales, the sales growth of the limited-edition
# scooter is 65% compared to the previous week, as compared with the 28% growth
# identified in the second activity of the chapter.
#
# While we have shown there to be a difference in sales between the two Bat Scooters,
# we also cannot rule out the fact that the sales differences can be attributed to the
# difference in the sales price of the two scooters, with the limited-edition scooter being
# $100 more expensive.

# %% [markdown]
# #### Analyzing the difference in the Sale Price Hypothesis
# If we consider the product list of scooters shown in Figure 9.23, and exclude
# the Bat model scooter, we can see that there are two price categories, 699.99 and
# above, or 499.99 and below. The Bat Scooter sits exactly between these two groups;
# perhaps the reduction in sales growth can be attributed to the different pricing model.
